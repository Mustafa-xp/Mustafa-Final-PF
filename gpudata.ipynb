# %%
import pandas as pd

df = pd.read_csv(r"gpu data.csv")

# %% [markdown]
# ## Name, Roll no. and Gitlink

# %% [markdown]
# Syed Mustafa Raza Zaidi , 078 and https://github.com/Mustafa-xp/Mustafa-Final-PF

# %%
df.shape
# Out:
# (48, 4)

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     48 non-null     object
#  1   Wattage  48 non-null     object
#  2   VRAM     48 non-null     object
#  3   3DMARK   48 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.6+ KB

# %%
column = list(df.columns)
column
# Out:
# ['Name', 'Wattage', 'VRAM', '3DMARK']

# %% [markdown]
# ##### Check Empty values

# %%
df.isna().sum()
# Out:
# Name       0
# Wattage    0
# VRAM       0
# 3DMARK     0
# dtype: int64

# %% [markdown]
# #### Cleaning empty set

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of                          Name Wattage  VRAM  3DMARK  col
# 0            GeForce GTX 1050     75W   2GB    1861    4
# 1         GeForce GTX 1050 Ti     75W   4GB    2356    4
# 2            GeForce GTX 1060    120W   6GB    4215    4
# 3            GeForce GTX 1650     75W   4GB    3552    4
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078    4
# 5         GeForce GTX 1660 Ti    120W   6GB    6373    4
# 6            GeForce RTX 2060    160W   6GB    7601    4
# 7         GeForce RTX 2080 Ti    250W  11GB   14628    4
# 8            GeForce RTX 3050    130W   8GB    6205    4
# 9            GeForce RTX 3060    170W  12GB    8739    4
# 10        GeForce RTX 3060 Ti    200W   8GB   11744    4
# 11           GeForce RTX 3070    220W   8GB   13663    4
# 12        GeForce RTX 3070 Ti    290W   8GB   14831    4
# 13           GeForce RTX 3080    320W  10GB   17656    4
# 14        GeForce RTX 3080 Ti    350W  12GB   19592    4
# 15           GeForce RTX 3090    350W  24GB   19901    4
# 16           GeForce RTX 4060    115W   8GB   10630    4
# 17        GeForce RTX 4060 Ti    160W   8GB   13462    4
# 18           GeForce RTX 4070    200W  12GB   17846    4
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214    4
# 20        GeForce RTX 4070 Ti    285W  12GB   22706    4
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426    4
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531    4
# 23           GeForce RTX 4090    450W  24GB   35966    4
# 24              Radeon R7 360    100W   2GB    1368    4
# 25              Radeon R9 370    150W   4GB    1456    4
# 26              Radeon R9 380    190W   4GB    2754    4
# 27              Radeon RX 460     75W   4GB    1760    4
# 28              Radeon RX 550     50W   4GB    1195    4
# 29              Radeon RX 560     80W   4GB    1860    4
# 30              Radeon RX 580    185W   8GB    4346    4
# 31             Radeon RX 6400     53W   4GB    3622    4
# 32          Radeon RX 6500 XT    107W   4GB    4973    4
# 33             Radeon RX 6600    132W   8GB    8158    4
# 34          Radeon RX 6600 XT    160W   8GB    9707    4
# 35          Radeon RX 6650 XT    176W   8GB   10027    4
# 36          Radeon RX 6700 XT    230W  12GB   12808    4
# 37          Radeon RX 6750 XT    250W  12GB   13595    4
# 38             Radeon RX 6800    250W  16GB   15972    4
# 39          Radeon RX 6800 XT    300W  16GB   19187    4
# 40          Radeon RX 6900 XT    300W  16GB   20621    4
# 41             Radeon RX 7600    165W   8GB   10817    4
# 42          Radeon RX 7600 XT    190W  16GB   11379    4
# 43          Radeon RX 7700 XT    245W  12GB   17245    4
# 44          Radeon RX 7800 XT    263W  16GB   19839    4
# 45         Radeon RX 7900 GRE    260W  16GB   21644    4
# 46          Radeon RX 7900 XT    315W  20GB   25617    4
# 47         Radeon RX 7900 XTX    355W  24GB   29246    4>

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Replace Empty values

# %%
df.fillna(17)

# %% [markdown]
# ### Replace specific columns

# %%
df['Name'].fillna(48)
# Out:
# 0              GeForce GTX 1050
# 1           GeForce GTX 1050 Ti
# 2              GeForce GTX 1060
# 3              GeForce GTX 1650
# 4        GeForce GTX 1660 SUPER
# 5           GeForce GTX 1660 Ti
# 6              GeForce RTX 2060
# 7           GeForce RTX 2080 Ti
# 8              GeForce RTX 3050
# 9              GeForce RTX 3060
# 10          GeForce RTX 3060 Ti
# 11             GeForce RTX 3070
# 12          GeForce RTX 3070 Ti
# 13             GeForce RTX 3080
# 14          GeForce RTX 3080 Ti
# 15             GeForce RTX 3090
# 16             GeForce RTX 4060
# 17          GeForce RTX 4060 Ti
# 18             GeForce RTX 4070
# 19       GeForce RTX 4070 SUPER
# 20          GeForce RTX 4070 Ti
# 21    GeForce RTX 4070 Ti SUPER
# 22       GeForce RTX 4080 SUPER
# 23             GeForce RTX 4090
# 24                Radeon R7 360
# 25                Radeon R9 370
# 26                Radeon R9 380
# 27                Radeon RX 460
# 28                Radeon RX 550
# 29                Radeon RX 560
# 30                Radeon RX 580
# 31               Radeon RX 6400
# 32            Radeon RX 6500 XT
# 33               Radeon RX 6600
# 34            Radeon RX 6600 XT
# 35            Radeon RX 6650 XT
# 36            Radeon RX 6700 XT
# 37            Radeon RX 6750 XT
# 38               Radeon RX 6800
# 39            Radeon RX 6800 XT
# 40            Radeon RX 6900 XT
# 41               Radeon RX 7600
# 42            Radeon RX 7600 XT
# 43            Radeon RX 7700 XT
# 44            Radeon RX 7800 XT
# 45           Radeon RX 7900 GRE
# 46            Radeon RX 7900 XT
# 47           Radeon RX 7900 XTX
# Name: Name, dtype: object

# %%
df['3DMARK'].mean() # the code wont be able to find the average if there's a non numerical number.
# Out:
# 12561.916666666666

# %%
df['VRAM'].mode()  # Common
# Out:
# 0    8GB
# Name: VRAM, dtype: object

# %%
df['3DMARK'].median()  # middle (doesnt calculate the middle one if any value is non numerical or commas are present)
# Out:
# 11561.5

# %% [markdown]
# ## Data Duplications

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#                          Name Wattage  VRAM  3DMARK
# 0            GeForce GTX 1050     75W   2GB    1861
# 1         GeForce GTX 1050 Ti     75W   4GB    2356
# 2            GeForce GTX 1060    120W   6GB    4215
# 3            GeForce GTX 1650     75W   4GB    3552
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078
# 5         GeForce GTX 1660 Ti    120W   6GB    6373
# 6            GeForce RTX 2060    160W   6GB    7601
# 7         GeForce RTX 2080 Ti    250W  11GB   14628
# 8            GeForce RTX 3050    130W   8GB    6205
# 9            GeForce RTX 3060    170W  12GB    8739
# 10        GeForce RTX 3060 Ti    200W   8GB   11744
# 11           GeForce RTX 3070    220W   8GB   13663
# 12        GeForce RTX 3070 Ti    290W   8GB   14831
# 13           GeForce RTX 3080    320W  10GB   17656
# 14        GeForce RTX 3080 Ti    350W  12GB   19592
# 15           GeForce RTX 3090    350W  24GB   19901
# 16           GeForce RTX 4060    115W   8GB   10630
# 17        GeForce RTX 4060 Ti    160W   8GB   13462
# 18           GeForce RTX 4070    200W  12GB   17846
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214
# 20        GeForce RTX 4070 Ti    285W  12GB   22706
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531
# 23           GeForce RTX 4090    450W  24GB   35966
# 24              Radeon R7 360    100W   2GB    1368
# 25              Radeon R9 370    150W   4GB    1456
# 26              Radeon R9 380    190W   4GB    2754
# 27              Radeon RX 460     75W   4GB    1760
# 28              Radeon RX 550     50W   4GB    1195
# 29              Radeon RX 560     80W   4GB    1860
# 30              Radeon RX 580    185W   8GB    4346
# 31             Radeon RX 6400     53W   4GB    3622
# 32          Radeon RX 6500 XT    107W   4GB    4973
# 33             Radeon RX 6600    132W   8GB    8158
# 34          Radeon RX 6600 XT    160W   8GB    9707
# 35          Radeon RX 6650 XT    176W   8GB   10027
# 36          Radeon RX 6700 XT    230W  12GB   12808
# 37          Radeon RX 6750 XT    250W  12GB   13595
# 38             Radeon RX 6800    250W  16GB   15972
# 39          Radeon RX 6800 XT    300W  16GB   19187
# 40          Radeon RX 6900 XT    300W  16GB   20621
# 41             Radeon RX 7600    165W   8GB   10817
# 42          Radeon RX 7600 XT    190W  16GB   11379
# 43          Radeon RX 7700 XT    245W  12GB   17245
# 44          Radeon RX 7800 XT    263W  16GB   19839
# 45         Radeon RX 7900 GRE    260W  16GB   21644
# 46          Radeon RX 7900 XT    315W  20GB   25617
# 47         Radeon RX 7900 XTX    355W  24GB   29246

# %%
df.describe()
# Out:
#              3DMARK
# count     48.000000
# mean   12561.916667
# std     8629.770759
# min     1195.000000
# 25%     4816.250000
# 50%    11561.500000
# 75%    19288.250000
# max    35966.000000

# %%
df.describe(include = "all").iloc[[0,6]] # includes all and tell the index and positions
# Out:
#       Name Wattage VRAM  3DMARK
# count   48      48   48    48.0
# min    NaN     NaN  NaN  1195.0

# %%
df.describe(include = "all").loc[["min","max"]] # includes all and tell the minimum and maximum values
# Out:
#     Name Wattage VRAM   3DMARK
# min  NaN     NaN  NaN   1195.0
# max  NaN     NaN  NaN  35966.0

# %% [markdown]
# ## Adding a column

# %%
df['col'] = 4
df
# Out:
#                          Name Wattage  VRAM  3DMARK  col
# 0            GeForce GTX 1050     75W   2GB    1861    4
# 1         GeForce GTX 1050 Ti     75W   4GB    2356    4
# 2            GeForce GTX 1060    120W   6GB    4215    4
# 3            GeForce GTX 1650     75W   4GB    3552    4
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078    4
# 5         GeForce GTX 1660 Ti    120W   6GB    6373    4
# 6            GeForce RTX 2060    160W   6GB    7601    4
# 7         GeForce RTX 2080 Ti    250W  11GB   14628    4
# 8            GeForce RTX 3050    130W   8GB    6205    4
# 9            GeForce RTX 3060    170W  12GB    8739    4
# 10        GeForce RTX 3060 Ti    200W   8GB   11744    4
# 11           GeForce RTX 3070    220W   8GB   13663    4
# 12        GeForce RTX 3070 Ti    290W   8GB   14831    4
# 13           GeForce RTX 3080    320W  10GB   17656    4
# 14        GeForce RTX 3080 Ti    350W  12GB   19592    4
# 15           GeForce RTX 3090    350W  24GB   19901    4
# 16           GeForce RTX 4060    115W   8GB   10630    4
# 17        GeForce RTX 4060 Ti    160W   8GB   13462    4
# 18           GeForce RTX 4070    200W  12GB   17846    4
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214    4
# 20        GeForce RTX 4070 Ti    285W  12GB   22706    4
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426    4
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531    4
# 23           GeForce RTX 4090    450W  24GB   35966    4
# 24              Radeon R7 360    100W   2GB    1368    4
# 25              Radeon R9 370    150W   4GB    1456    4
# 26              Radeon R9 380    190W   4GB    2754    4
# 27              Radeon RX 460     75W   4GB    1760    4
# 28              Radeon RX 550     50W   4GB    1195    4
# 29              Radeon RX 560     80W   4GB    1860    4
# 30              Radeon RX 580    185W   8GB    4346    4
# 31             Radeon RX 6400     53W   4GB    3622    4
# 32          Radeon RX 6500 XT    107W   4GB    4973    4
# 33             Radeon RX 6600    132W   8GB    8158    4
# 34          Radeon RX 6600 XT    160W   8GB    9707    4
# 35          Radeon RX 6650 XT    176W   8GB   10027    4
# 36          Radeon RX 6700 XT    230W  12GB   12808    4
# 37          Radeon RX 6750 XT    250W  12GB   13595    4
# 38             Radeon RX 6800    250W  16GB   15972    4
# 39          Radeon RX 6800 XT    300W  16GB   19187    4
# 40          Radeon RX 6900 XT    300W  16GB   20621    4
# 41             Radeon RX 7600    165W   8GB   10817    4
# 42          Radeon RX 7600 XT    190W  16GB   11379    4
# 43          Radeon RX 7700 XT    245W  12GB   17245    4
# 44          Radeon RX 7800 XT    263W  16GB   19839    4
# 45         Radeon RX 7900 GRE    260W  16GB   21644    4
# 46          Radeon RX 7900 XT    315W  20GB   25617    4
# 47         Radeon RX 7900 XTX    355W  24GB   29246    4

# %% [markdown]
# ## Remove a column

# %%
df.drop(columns=['col'], inplace=True, errors='ignore')
df
# Out:
#                          Name Wattage  VRAM  3DMARK
# 0            GeForce GTX 1050     75W   2GB    1861
# 1         GeForce GTX 1050 Ti     75W   4GB    2356
# 2            GeForce GTX 1060    120W   6GB    4215
# 3            GeForce GTX 1650     75W   4GB    3552
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078
# 5         GeForce GTX 1660 Ti    120W   6GB    6373
# 6            GeForce RTX 2060    160W   6GB    7601
# 7         GeForce RTX 2080 Ti    250W  11GB   14628
# 8            GeForce RTX 3050    130W   8GB    6205
# 9            GeForce RTX 3060    170W  12GB    8739
# 10        GeForce RTX 3060 Ti    200W   8GB   11744
# 11           GeForce RTX 3070    220W   8GB   13663
# 12        GeForce RTX 3070 Ti    290W   8GB   14831
# 13           GeForce RTX 3080    320W  10GB   17656
# 14        GeForce RTX 3080 Ti    350W  12GB   19592
# 15           GeForce RTX 3090    350W  24GB   19901
# 16           GeForce RTX 4060    115W   8GB   10630
# 17        GeForce RTX 4060 Ti    160W   8GB   13462
# 18           GeForce RTX 4070    200W  12GB   17846
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214
# 20        GeForce RTX 4070 Ti    285W  12GB   22706
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531
# 23           GeForce RTX 4090    450W  24GB   35966
# 24              Radeon R7 360    100W   2GB    1368
# 25              Radeon R9 370    150W   4GB    1456
# 26              Radeon R9 380    190W   4GB    2754
# 27              Radeon RX 460     75W   4GB    1760
# 28              Radeon RX 550     50W   4GB    1195
# 29              Radeon RX 560     80W   4GB    1860
# 30              Radeon RX 580    185W   8GB    4346
# 31             Radeon RX 6400     53W   4GB    3622
# 32          Radeon RX 6500 XT    107W   4GB    4973
# 33             Radeon RX 6600    132W   8GB    8158
# 34          Radeon RX 6600 XT    160W   8GB    9707
# 35          Radeon RX 6650 XT    176W   8GB   10027
# 36          Radeon RX 6700 XT    230W  12GB   12808
# 37          Radeon RX 6750 XT    250W  12GB   13595
# 38             Radeon RX 6800    250W  16GB   15972
# 39          Radeon RX 6800 XT    300W  16GB   19187
# 40          Radeon RX 6900 XT    300W  16GB   20621
# 41             Radeon RX 7600    165W   8GB   10817
# 42          Radeon RX 7600 XT    190W  16GB   11379
# 43          Radeon RX 7700 XT    245W  12GB   17245
# 44          Radeon RX 7800 XT    263W  16GB   19839
# 45         Radeon RX 7900 GRE    260W  16GB   21644
# 46          Radeon RX 7900 XT    315W  20GB   25617
# 47         Radeon RX 7900 XTX    355W  24GB   29246

# %% [markdown]
# ## Adding a row

# %%
a = {
    'Name': 'New GPU',  
    'Wattage': 200,           
    'VRAM': 12,              
    '3DMARK': 15000,          
}

df = pd.concat([df, pd.DataFrame([a])], ignore_index=True)
df
# Out:
#                          Name Wattage  VRAM  3DMARK
# 0            GeForce GTX 1050     75W   2GB    1861
# 1         GeForce GTX 1050 Ti     75W   4GB    2356
# 2            GeForce GTX 1060    120W   6GB    4215
# 3            GeForce GTX 1650     75W   4GB    3552
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078
# 5         GeForce GTX 1660 Ti    120W   6GB    6373
# 6            GeForce RTX 2060    160W   6GB    7601
# 7         GeForce RTX 2080 Ti    250W  11GB   14628
# 8            GeForce RTX 3050    130W   8GB    6205
# 9            GeForce RTX 3060    170W  12GB    8739
# 10        GeForce RTX 3060 Ti    200W   8GB   11744
# 11           GeForce RTX 3070    220W   8GB   13663
# 12        GeForce RTX 3070 Ti    290W   8GB   14831
# 13           GeForce RTX 3080    320W  10GB   17656
# 14        GeForce RTX 3080 Ti    350W  12GB   19592
# 15           GeForce RTX 3090    350W  24GB   19901
# 16           GeForce RTX 4060    115W   8GB   10630
# 17        GeForce RTX 4060 Ti    160W   8GB   13462
# 18           GeForce RTX 4070    200W  12GB   17846
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214
# 20        GeForce RTX 4070 Ti    285W  12GB   22706
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531
# 23           GeForce RTX 4090    450W  24GB   35966
# 24              Radeon R7 360    100W   2GB    1368
# 25              Radeon R9 370    150W   4GB    1456
# 26              Radeon R9 380    190W   4GB    2754
# 27              Radeon RX 460     75W   4GB    1760
# 28              Radeon RX 550     50W   4GB    1195
# 29              Radeon RX 560     80W   4GB    1860
# 30              Radeon RX 580    185W   8GB    4346
# 31             Radeon RX 6400     53W   4GB    3622
# 32          Radeon RX 6500 XT    107W   4GB    4973
# 33             Radeon RX 6600    132W   8GB    8158
# 34          Radeon RX 6600 XT    160W   8GB    9707
# 35          Radeon RX 6650 XT    176W   8GB   10027
# 36          Radeon RX 6700 XT    230W  12GB   12808
# 37          Radeon RX 6750 XT    250W  12GB   13595
# 38             Radeon RX 6800    250W  16GB   15972
# 39          Radeon RX 6800 XT    300W  16GB   19187
# 40          Radeon RX 6900 XT    300W  16GB   20621
# 41             Radeon RX 7600    165W   8GB   10817
# 42          Radeon RX 7600 XT    190W  16GB   11379
# 43          Radeon RX 7700 XT    245W  12GB   17245
# 44          Radeon RX 7800 XT    263W  16GB   19839
# 45         Radeon RX 7900 GRE    260W  16GB   21644
# 46          Radeon RX 7900 XT    315W  20GB   25617
# 47         Radeon RX 7900 XTX    355W  24GB   29246
# 48                    New GPU     200    12   15000
# 49                    New GPU     200    12   15000
# 50                    New GPU     200    12   15000
# 51                    New GPU     200    12   15000
# 52                    New GPU     200    12   15000
# 53                    New GPU     200    12   15000
# 54                    New GPU     200    12   15000

# %% [markdown]
# ## Remove a row

# %%
df.drop(50,inplace=True) # it removed my 0,50,51 and 53 index
df
# Out:
#                          Name Wattage  VRAM  3DMARK
# 1         GeForce GTX 1050 Ti     75W   4GB    2356
# 2            GeForce GTX 1060    120W   6GB    4215
# 3            GeForce GTX 1650     75W   4GB    3552
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078
# 5         GeForce GTX 1660 Ti    120W   6GB    6373
# 6            GeForce RTX 2060    160W   6GB    7601
# 7         GeForce RTX 2080 Ti    250W  11GB   14628
# 8            GeForce RTX 3050    130W   8GB    6205
# 9            GeForce RTX 3060    170W  12GB    8739
# 10        GeForce RTX 3060 Ti    200W   8GB   11744
# 11           GeForce RTX 3070    220W   8GB   13663
# 12        GeForce RTX 3070 Ti    290W   8GB   14831
# 13           GeForce RTX 3080    320W  10GB   17656
# 14        GeForce RTX 3080 Ti    350W  12GB   19592
# 15           GeForce RTX 3090    350W  24GB   19901
# 16           GeForce RTX 4060    115W   8GB   10630
# 17        GeForce RTX 4060 Ti    160W   8GB   13462
# 18           GeForce RTX 4070    200W  12GB   17846
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214
# 20        GeForce RTX 4070 Ti    285W  12GB   22706
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531
# 23           GeForce RTX 4090    450W  24GB   35966
# 24              Radeon R7 360    100W   2GB    1368
# 25              Radeon R9 370    150W   4GB    1456
# 26              Radeon R9 380    190W   4GB    2754
# 27              Radeon RX 460     75W   4GB    1760
# 28              Radeon RX 550     50W   4GB    1195
# 29              Radeon RX 560     80W   4GB    1860
# 30              Radeon RX 580    185W   8GB    4346
# 31             Radeon RX 6400     53W   4GB    3622
# 32          Radeon RX 6500 XT    107W   4GB    4973
# 33             Radeon RX 6600    132W   8GB    8158
# 34          Radeon RX 6600 XT    160W   8GB    9707
# 35          Radeon RX 6650 XT    176W   8GB   10027
# 36          Radeon RX 6700 XT    230W  12GB   12808
# 37          Radeon RX 6750 XT    250W  12GB   13595
# 38             Radeon RX 6800    250W  16GB   15972
# 39          Radeon RX 6800 XT    300W  16GB   19187
# 40          Radeon RX 6900 XT    300W  16GB   20621
# 41             Radeon RX 7600    165W   8GB   10817
# 42          Radeon RX 7600 XT    190W  16GB   11379
# 43          Radeon RX 7700 XT    245W  12GB   17245
# 44          Radeon RX 7800 XT    263W  16GB   19839
# 45         Radeon RX 7900 GRE    260W  16GB   21644
# 46          Radeon RX 7900 XT    315W  20GB   25617
# 47         Radeon RX 7900 XTX    355W  24GB   29246
# 48                    New GPU     200    12   15000
# 49                    New GPU     200    12   15000
# 52                    New GPU     200    12   15000
# 54                    New GPU     200    12   15000

# %% [markdown]
# ## Slicing

# %%
df[1:7]
# Out:
#                      Name Wattage  VRAM  3DMARK
# 2        GeForce GTX 1060    120W   6GB    4215
# 3        GeForce GTX 1650     75W   4GB    3552
# 4  GeForce GTX 1660 SUPER    125W   6GB    6078
# 5     GeForce GTX 1660 Ti    120W   6GB    6373
# 6        GeForce RTX 2060    160W   6GB    7601
# 7     GeForce RTX 2080 Ti    250W  11GB   14628

# %%
df[2:20:3]
# Out:
#                    Name Wattage  VRAM  3DMARK
# 3      GeForce GTX 1650     75W   4GB    3552
# 6      GeForce RTX 2060    160W   6GB    7601
# 9      GeForce RTX 3060    170W  12GB    8739
# 12  GeForce RTX 3070 Ti    290W   8GB   14831
# 15     GeForce RTX 3090    350W  24GB   19901
# 18     GeForce RTX 4070    200W  12GB   17846

# %%
df[2:20:3]
# Out:
#                          Name
# 14        GeForce RTX 3080 Ti
# 15           GeForce RTX 3090
# 16           GeForce RTX 4060
# 17        GeForce RTX 4060 Ti
# 18           GeForce RTX 4070
# 19     GeForce RTX 4070 SUPER
# 20        GeForce RTX 4070 Ti
# 21  GeForce RTX 4070 Ti SUPER
# 22     GeForce RTX 4080 SUPER
# 23           GeForce RTX 4090
# 24              Radeon R7 360
# 25              Radeon R9 370
# 26              Radeon R9 380
# 27              Radeon RX 460
# 28              Radeon RX 550
# 29              Radeon RX 560
# 30              Radeon RX 580
# 31             Radeon RX 6400
# 32          Radeon RX 6500 XT
# 33             Radeon RX 6600
# 34          Radeon RX 6600 XT
# 35          Radeon RX 6650 XT
# 36          Radeon RX 6700 XT
# 37          Radeon RX 6750 XT
# 38             Radeon RX 6800
# 39          Radeon RX 6800 XT
# 40          Radeon RX 6900 XT

# %% [markdown]
# ## Flowcharts

# %%
df['VRAM'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='VRAM'>

# %%
df['Name'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Name'>

# %%
df['Wattage'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['3DMARK'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Name'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['VRAM'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='VRAM'>

# %%
df['Wattage'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['3DMARK'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Data Aggretion

# %%
df[['Name', '3DMARK']].aggregate(['sum', 'min'])
# Out:
#                                                   Name  3DMARK
# sum  GeForce GTX 1050 TiGeForce GTX 1060GeForce GTX...  661111
# min                                GeForce GTX 1050 Ti    1195

# %% [markdown]
# #### sum()

# %%
df['3DMARK'].sum()
# Out:
# 661111

# %% [markdown]
# #### std() (Standard Deviation)

# %%
df['3DMARK'].std()
# Out:
# 8247.779174931356

# %% [markdown]
# #### var() Variance Calculation

# %%
df['3DMARK'].var()
# Out:
# 68025861.31843138

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum() # it only shows the empty values and taking the sum of the dataframe
# Out:
# Name       0
# Wattage    0
# VRAM       0
# 3DMARK     0
# dtype: int64

# %% [markdown]
# #### rename() Rename Columns

# %%
df.rename(columns={'Name': 'Variant'}, inplace=True)
df
# Out:
#                       Variant Wattage  VRAM  3DMARK
# 0            GeForce GTX 1050     75W   2GB    1861
# 1         GeForce GTX 1050 Ti     75W   4GB    2356
# 2            GeForce GTX 1060    120W   6GB    4215
# 3            GeForce GTX 1650     75W   4GB    3552
# 4      GeForce GTX 1660 SUPER    125W   6GB    6078
# 5         GeForce GTX 1660 Ti    120W   6GB    6373
# 6            GeForce RTX 2060    160W   6GB    7601
# 7         GeForce RTX 2080 Ti    250W  11GB   14628
# 8            GeForce RTX 3050    130W   8GB    6205
# 9            GeForce RTX 3060    170W  12GB    8739
# 10        GeForce RTX 3060 Ti    200W   8GB   11744
# 11           GeForce RTX 3070    220W   8GB   13663
# 12        GeForce RTX 3070 Ti    290W   8GB   14831
# 13           GeForce RTX 3080    320W  10GB   17656
# 14        GeForce RTX 3080 Ti    350W  12GB   19592
# 15           GeForce RTX 3090    350W  24GB   19901
# 16           GeForce RTX 4060    115W   8GB   10630
# 17        GeForce RTX 4060 Ti    160W   8GB   13462
# 18           GeForce RTX 4070    200W  12GB   17846
# 19     GeForce RTX 4070 SUPER    220W  12GB   21214
# 20        GeForce RTX 4070 Ti    285W  12GB   22706
# 21  GeForce RTX 4070 Ti SUPER    285W  16GB   24426
# 22     GeForce RTX 4080 SUPER    320W  16GB   28531
# 23           GeForce RTX 4090    450W  24GB   35966
# 24              Radeon R7 360    100W   2GB    1368
# 25              Radeon R9 370    150W   4GB    1456
# 26              Radeon R9 380    190W   4GB    2754
# 27              Radeon RX 460     75W   4GB    1760
# 28              Radeon RX 550     50W   4GB    1195
# 29              Radeon RX 560     80W   4GB    1860
# 30              Radeon RX 580    185W   8GB    4346
# 31             Radeon RX 6400     53W   4GB    3622
# 32          Radeon RX 6500 XT    107W   4GB    4973
# 33             Radeon RX 6600    132W   8GB    8158
# 34          Radeon RX 6600 XT    160W   8GB    9707
# 35          Radeon RX 6650 XT    176W   8GB   10027
# 36          Radeon RX 6700 XT    230W  12GB   12808
# 37          Radeon RX 6750 XT    250W  12GB   13595
# 38             Radeon RX 6800    250W  16GB   15972
# 39          Radeon RX 6800 XT    300W  16GB   19187
# 40          Radeon RX 6900 XT    300W  16GB   20621
# 41             Radeon RX 7600    165W   8GB   10817
# 42          Radeon RX 7600 XT    190W  16GB   11379
# 43          Radeon RX 7700 XT    245W  12GB   17245
# 44          Radeon RX 7800 XT    263W  16GB   19839
# 45         Radeon RX 7900 GRE    260W  16GB   21644
# 46          Radeon RX 7900 XT    315W  20GB   25617
# 47         Radeon RX 7900 XTX    355W  24GB   29246

# %% [markdown]
# ## Data Saving

# %%
df = pd.read_csv("gpu data.csv")

df.to_excel("final project.xlsx", index=False)
